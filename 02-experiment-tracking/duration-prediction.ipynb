# %%
# !python -V
# Out:
# Python 3.12.4

# %%
import pandas as pd

# %%
import pickle

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import root_mean_squared_error

# %%
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# <Experiment: artifact_location='/Users/emma_factored/learning/mlops-zoomcamp/02-experiment-tracking/mlruns/1', creation_time=1721145255187, experiment_id='1', last_update_time=1721145255187, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
df = pd.read_parquet('./data/green_tripdata_2021-01.parquet')

df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

df = df[(df.duration >= 1) & (df.duration <= 60)]

categorical = ['PULocationID', 'DOLocationID']
numerical = ['trip_distance']

df[categorical] = df[categorical].astype(str)

# %%
train_dicts = df[categorical + numerical].to_dict(orient='records')

dv = DictVectorizer()
X_train = dv.fit_transform(train_dicts)

target = 'duration'
y_train = df[target].values

lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_train)

root_mean_squared_error(y_train, y_pred)
# Out:
# 9.838799799829445

# %%
sns.histplot(y_pred, label='prediction', kde=True, stat="density", linewidth=0)
sns.histplot(y_train, label='actual', kde=True, stat="density", linewidth=0)
plt.legend()

# %%
def read_dataframe(filename):
    if filename.endswith('.csv'):
        df = pd.read_csv(filename)

        df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
        df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    elif filename.endswith('.parquet'):
        df = pd.read_parquet(filename)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = read_dataframe('./data/green_tripdata_2021-01.parquet')
df_val = read_dataframe('./data/green_tripdata_2021-02.parquet')

# %%
len(df_train), len(df_val)
# Out:
# (73908, 61921)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

root_mean_squared_error(y_val, y_pred)
# Out:
# 7.758715208946364

# %%
with open('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
with mlflow.start_run():
    
    mlflow.set_tag("developer", "Emma")
    
    mlflow.log_param("train-data-path", "./data/green_tripdata_2021-01.parquet")
    mlflow.log_param("valid-data-path", "./data/green_tripdata_2021-02.parquet")

    alpha = 0.1
    mlflow.log_param("alpha", alpha)
    
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)
    
    y_pred = lr.predict(X_val)
    
    rmse = root_mean_squared_error(y_val, y_pred)
    mlflow.log_metric("rmse", rmse)

    mlflow.log_artifact(local_path="models/lin_reg.bin", artifact_path="models_pickle")
# Out:
# 2024/07/16 13:49:56 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'

# %%
import xgboost as xgb

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = root_mean_squared_error(y_val, y_pred)
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:squarederror',
    'seed': 42
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
# [0]	validation-rmse:10.83326
# [1]	validation-rmse:9.76769
# [2]	validation-rmse:8.95416
# [3]	validation-rmse:8.34129
# [4]	validation-rmse:7.88477
# [5]	validation-rmse:7.54807
# [6]	validation-rmse:7.29954
# [7]	validation-rmse:7.11789
# [8]	validation-rmse:6.98373
# [9]	validation-rmse:6.88509
# [10]	validation-rmse:6.81201
# [11]	validation-rmse:6.75687
# [12]	validation-rmse:6.71410
# [13]	validation-rmse:6.68200
# [14]	validation-rmse:6.65613
# [15]	validation-rmse:6.63616
# [16]	validation-rmse:6.62063
# [17]	validation-rmse:6.60733
# [18]	validation-rmse:6.59662
# [19]	validation-rmse:6.58779
# [20]	validation-rmse:6.58003
# [21]	validation-rmse:6.57383
# [22]	validation-rmse:6.56889
# [23]	validation-rmse:6.56532
# [24]	validation-rmse:6.56095
# [25]	validation-rmse:6.55490
# [26]	validation-rmse:6.55186
# [27]	validation-rmse:6.54781
# [28]	validation-rmse:6.54579
# [29]	validation-rmse:6.54465
# [30]	validation-rmse:6.54297
# [31]	validation-rmse:6.54135
# [32]	validation-rmse:6.53896
# [33]	validation-rmse:6.53764
# [34]	validation-rmse:6.53670
# [35]	validation-rmse:6.53531
# [36]	validation-rmse:6.53203
# [37]	validation-rmse:6.53099
# [38]	validation-rmse:6.52979
# [39]	validation-rmse:6.52853
# [40]	validation-rmse:6.52798
# [41]	validation-rmse:6.52675
# [42]	validation-rmse:6.52502
# [43]	validation-rmse:6.52394
# [44]	validation-rmse:6.52313
# [45]	validation-rmse:6.52187
# [46]	validation-rmse:6.52061
# [47]	validation-rmse:6.51956
# [48]	validation-rmse:6.51822
# [49]	validation-rmse:6.51742
# [50]	validation-rmse:6.51678
# [51]	validation-rmse:6.51627
# [52]	validation-rmse:6.51481
# [53]	validation-rmse:6.51392
# [54]	validation-rmse:6.51341
# [55]	validation-rmse:6.51260
# [56]	validation-rmse:6.51161
# [57]	validation-rmse:6.51049
# [58]	validation-rmse:6.50988
# [59]	validation-rmse:6.50911
# [60]	validation-rmse:6.50821
# [61]	validation-rmse:6.50736
# [62]	validation-rmse:6.50676
# [63]	validation-rmse:6.50606
# [64]	validation-rmse:6.50500
# [65]	validation-rmse:6.50452
# [66]	validation-rmse:6.50379
# [67]	validation-rmse:6.50318
# [68]	validation-rmse:6.50243
# [69]	validation-rmse:6.50154
# [70]	validation-rmse:6.50123
# [71]	validation-rmse:6.50062
# [72]	validation-rmse:6.49992
# [73]	validation-rmse:6.49955
# [74]	validation-rmse:6.49896
# [75]	validation-rmse:6.49817
# [76]	validation-rmse:6.49739
# [77]	validation-rmse:6.49695
# [78]	validation-rmse:6.49657
# [79]	validation-rmse:6.49584
# [80]	validation-rmse:6.49535
# [81]	validation-rmse:6.49456
# [82]	validation-rmse:6.49387
# [83]	validation-rmse:6.49353
# [84]	validation-rmse:6.49325
# [85]	validation-rmse:6.49279
# [86]	validation-rmse:6.49221
# [87]	validation-rmse:6.49186
# [88]	validation-rmse:6.49154
# [89]	validation-rmse:6.49097
# [90]	validation-rmse:6.49050
# [91]	validation-rmse:6.49008
# [92]	validation-rmse:6.48926
# [93]	validation-rmse:6.48875
# [94]	validation-rmse:6.48823
# [95]	validation-rmse:6.48795
# [96]	validation-rmse:6.48758
# [97]	validation-rmse:6.48723
# [98]	validation-rmse:6.48682
# [99]	validation-rmse:6.48583
# [100]	validation-rmse:6.48544
# [101]	validation-rmse:6.48489
# [102]	validation-rmse:6.48457
# [103]	validation-rmse:6.48425
# [104]	validation-rmse:6.48353
# [105]	validation-rmse:6.48295
# [106]	validation-rmse:6.48273
# [107]	validation-rmse:6.48269
# [108]	validation-rmse:6.48232
# [109]	validation-rmse:6.48195
# [110]	validation-rmse:6.48123
# [111]	validation-rmse:6.48077
# [112]	validation-rmse:6.48028
# [113]	validation-rmse:6.48017
# [114]	validation-rmse:6.47997
# [115]	validation-rmse:6.47916
# [116]	validation-rmse:6.47893
# [117]	validation-rmse:6.47839
# [118]	validation-rmse:6.47805
# [119]	validation-rmse:6.47770
# [120]	validation-rmse:6.47718
# [121]	validation-rmse:6.47691
# [122]	validation-rmse:6.47656
# [123]	validation-rmse:6.47610
# [124]	validation-rmse:6.47589
# [125]	validation-rmse:6.47505
# [126]	validation-rmse:6.47483
# [127]	validation-rmse:6.47455
# [128]	validation-rmse:6.47423
# [129]	validation-rmse:6.47396
# [130]	validation-rmse:6.47358
# [131]	validation-rmse:6.47321
# [132]	validation-rmse:6.47303
# [133]	validation-rmse:6.47294
# [134]	validation-rmse:6.47286
# [135]	validation-rmse:6.47265
# [136]	validation-rmse:6.47226
# [137]	validation-rmse:6.47181
# [138]	validation-rmse:6.47114
# [139]	validation-rmse:6.47091
# [140]	validation-rmse:6.47070
# [141]	validation-rmse:6.47030
# [142]	validation-rmse:6.47042
# [143]	validation-rmse:6.47006
# [144]	validation-rmse:6.46984
# [145]	validation-rmse:6.46958
# [146]	validation-rmse:6.46926
# [147]	validation-rmse:6.46868
# [148]	validation-rmse:6.46837
# [149]	validation-rmse:6.46793
# [150]	validation-rmse:6.46751
# [151]	validation-rmse:6.46743
# [152]	validation-rmse:6.46734
# [153]	validation-rmse:6.46718
# [154]	validation-rmse:6.46675
# [155]	validation-rmse:6.46663
# [156]	validation-rmse:6.46643
# [157]	validation-rmse:6.46637
# [158]	validation-rmse:6.46629
# [159]	validation-rmse:6.46617
# [160]	validation-rmse:6.46579
# [161]	validation-rmse:6.46544
# [162]	validation-rmse:6.46514
# [163]	validation-rmse:6.46492
# [164]	validation-rmse:6.46436
# [165]	validation-rmse:6.46412
# [166]	validation-rmse:6.46393
# [167]	validation-rmse:6.46367
# [168]	validation-rmse:6.46327
# [169]	validation-rmse:6.46291
# [170]	validation-rmse:6.46270
# [171]	validation-rmse:6.46248
# [172]	validation-rmse:6.46222
# [173]	validation-rmse:6.46203
# [174]	validation-rmse:6.46189
# [175]	validation-rmse:6.46160
# [176]	validation-rmse:6.46093
# [177]	validation-rmse:6.46055
# [178]	validation-rmse:6.46064
# [179]	validation-rmse:6.46065
# [180]	validation-rmse:6.46054
# [181]	validation-rmse:6.46018
# [182]	validation-rmse:6.46007
# [183]	validation-rmse:6.46003
# [184]	validation-rmse:6.45984
# [185]	validation-rmse:6.45970
# [186]	validation-rmse:6.45959
# [187]	validation-rmse:6.45935
# [188]	validation-rmse:6.45908
# [189]	validation-rmse:6.45893
# [190]	validation-rmse:6.45869
# [191]	validation-rmse:6.45807
# [192]	validation-rmse:6.45795
# [193]	validation-rmse:6.45764
# [194]	validation-rmse:6.45730
# [195]	validation-rmse:6.45725
# [196]	validation-rmse:6.45724
# [197]	validation-rmse:6.45724
# [198]	validation-rmse:6.45705
# [199]	validation-rmse:6.45694
# [200]	validation-rmse:6.45679
# [201]	validation-rmse:6.45658
# [202]	validation-rmse:6.45636
# [203]	validation-rmse:6.45625
# [204]	validation-rmse:6.45599
# [205]	validation-rmse:6.45534
# [206]	validation-rmse:6.45510
# [207]	validation-rmse:6.45484
# [208]	validation-rmse:6.45480
# [209]	validation-rmse:6.45462
# [210]	validation-rmse:6.45471
# [211]	validation-rmse:6.45390
# [212]	validation-rmse:6.45374
# [213]	validation-rmse:6.45353
# [214]	validation-rmse:6.45308
# [215]	validation-rmse:6.45291
# [216]	validation-rmse:6.45257
# [217]	validation-rmse:6.45210
# [218]	validation-rmse:6.45192
# [219]	validation-rmse:6.45186
# [220]	validation-rmse:6.45160
# [221]	validation-rmse:6.45176
# [222]	validation-rmse:6.45165
# [223]	validation-rmse:6.45127
# [224]	validation-rmse:6.45107
# [225]	validation-rmse:6.45102
# [226]	validation-rmse:6.45082
# [227]	validation-rmse:6.45069
# [228]	validation-rmse:6.45050
# [229]	validation-rmse:6.45037
# [230]	validation-rmse:6.45002
# [231]	validation-rmse:6.44986
# [232]	validation-rmse:6.44983
# [233]	validation-rmse:6.44955
# [234]	validation-rmse:6.44948
# [235]	validation-rmse:6.44935
# [236]	validation-rmse:6.44909
# [237]	validation-rmse:6.44854
# [238]	validation-rmse:6.44845
# [239]	validation-rmse:6.44832
# [240]	validation-rmse:6.44822
# [241]	validation-rmse:6.44808
# [242]	validation-rmse:6.44792
# [243]	validation-rmse:6.44773
# [244]	validation-rmse:6.44763
# [245]	validation-rmse:6.44736
# [246]	validation-rmse:6.44726
# [247]	validation-rmse:6.44730
# [248]	validation-rmse:6.44714
# [249]	validation-rmse:6.44718
# [250]	validation-rmse:6.44708
# [251]	validation-rmse:6.44713
# [252]	validation-rmse:6.44690
# [253]	validation-rmse:6.44683
# [254]	validation-rmse:6.44689
# [255]	validation-rmse:6.44676
# [256]	validation-rmse:6.44669
# [257]	validation-rmse:6.44646
# [258]	validation-rmse:6.44651
# [259]	validation-rmse:6.44602
# [260]	validation-rmse:6.44589
# [261]	validation-rmse:6.44574
# [262]	validation-rmse:6.44561
# [263]	validation-rmse:6.44559
# [264]	validation-rmse:6.44563
# [265]	validation-rmse:6.44540
# [266]	validation-rmse:6.44531
# [267]	validation-rmse:6.44493
# [268]	validation-rmse:6.44477
# [269]	validation-rmse:6.44468
# [270]	validation-rmse:6.44377
# [271]	validation-rmse:6.44363
# [272]	validation-rmse:6.44335
# [273]	validation-rmse:6.44322
# [274]	validation-rmse:6.44313
# [275]	validation-rmse:6.44315
# [276]	validation-rmse:6.44316
# [277]	validation-rmse:6.44306
# [278]	validation-rmse:6.44292
# [279]	validation-rmse:6.44297
# [280]	validation-rmse:6.44261
# [281]	validation-rmse:6.44240
# [282]	validation-rmse:6.44259
# [283]	validation-rmse:6.44249
# [284]	validation-rmse:6.44232
# ...
# [11]	validation-rmse:6.59655
# [12]	validation-rmse:6.56119
# [13]	validation-rmse:6.53617
# [14]	validation-rmse:6.51484
# [15]	validation-rmse:6.49713
# [16]	validation-rmse:6.48434
# [17]	validation-rmse:6.47225
# [18]	validation-rmse:6.46461
# [19]	validation-rmse:6.45742
# [20]	validation-rmse:6.45146
# [21]	validation-rmse:6.44707
# [22]	validation-rmse:6.44344
# [23]	validation-rmse:6.43991
# [24]	validation-rmse:6.43710
# [25]	validation-rmse:6.43473
# [26]	validation-rmse:6.43321
# [27]	validation-rmse:6.43146
# [28]	validation-rmse:6.42890
# [29]	validation-rmse:6.42686
# [30]	validation-rmse:6.42554
# [31]	validation-rmse:6.42379
# [32]	validation-rmse:6.42222
# [33]	validation-rmse:6.42018
# [34]	validation-rmse:6.41862
# [35]	validation-rmse:6.41801
# [36]	validation-rmse:6.41650
# [37]	validation-rmse:6.41520
# [38]	validation-rmse:6.41270
# [39]	validation-rmse:6.41167
# [40]	validation-rmse:6.40999
# [41]	validation-rmse:6.40805
# [42]	validation-rmse:6.40614
# [43]	validation-rmse:6.40476
# [44]	validation-rmse:6.40309
# [45]	validation-rmse:6.40146
# [46]	validation-rmse:6.40013
# [47]	validation-rmse:6.39886
# [48]	validation-rmse:6.39814
# [49]	validation-rmse:6.39726
# [50]	validation-rmse:6.39630
# [51]	validation-rmse:6.39470
# [52]	validation-rmse:6.39335
# [53]	validation-rmse:6.39220
# [54]	validation-rmse:6.39064
# [55]	validation-rmse:6.38972
# [56]	validation-rmse:6.38912
# [57]	validation-rmse:6.38818
# [58]	validation-rmse:6.38661
# [59]	validation-rmse:6.38564
# [60]	validation-rmse:6.38490
# [61]	validation-rmse:6.38413
# [62]	validation-rmse:6.38313
# [63]	validation-rmse:6.38235
# [64]	validation-rmse:6.38115
# [65]	validation-rmse:6.38038
# [66]	validation-rmse:6.37937
# [67]	validation-rmse:6.37808
# [68]	validation-rmse:6.37660
# [69]	validation-rmse:6.37556
# [70]	validation-rmse:6.37472
# [71]	validation-rmse:6.37401
# [72]	validation-rmse:6.37320
# [73]	validation-rmse:6.37231
# [74]	validation-rmse:6.37145
# [75]	validation-rmse:6.37102
# [76]	validation-rmse:6.37026
# [77]	validation-rmse:6.36974
# [78]	validation-rmse:6.36923
# [79]	validation-rmse:6.36855
# [80]	validation-rmse:6.36752
# [81]	validation-rmse:6.36665
# [82]	validation-rmse:6.36613
# [83]	validation-rmse:6.36606
# [84]	validation-rmse:6.36524
# [85]	validation-rmse:6.36487
# [86]	validation-rmse:6.36415
# [87]	validation-rmse:6.36410
# [88]	validation-rmse:6.36361
# [89]	validation-rmse:6.36255
# [90]	validation-rmse:6.36159
# [91]	validation-rmse:6.36126
# [92]	validation-rmse:6.36087
# [93]	validation-rmse:6.36056
# [94]	validation-rmse:6.36013
# [95]	validation-rmse:6.35946
# [96]	validation-rmse:6.35873
# [97]	validation-rmse:6.35806
# [98]	validation-rmse:6.35767
# [99]	validation-rmse:6.35717
# [100]	validation-rmse:6.35621
# [101]	validation-rmse:6.35533
# [102]	validation-rmse:6.35469
# [103]	validation-rmse:6.35415
# [104]	validation-rmse:6.35402
# [105]	validation-rmse:6.35373
# [106]	validation-rmse:6.35366

# %%
mlflow.xgboost.autolog(disable=True)
with mlflow.start_run():
    
    train = xgb.DMatrix(X_train, label=y_train)
    valid = xgb.DMatrix(X_val, label=y_val)

    best_params = {
        'learning_rate': 0.14172853517590822,
        'max_depth': 62,
        'min_child_weight': 1.8004685252882509,
        'objective': 'reg:squarederror',
        'reg_alpha': 0.010261295539085922,
        'reg_lambda': 0.345161763617992,
        'seed': 42
    }

    mlflow.log_params(best_params)

    booster = xgb.train(
        params=best_params,
        dtrain=train,
        num_boost_round=1000,
        evals=[(valid, 'validation')],
        early_stopping_rounds=50
    )

    y_pred = booster.predict(valid)
    rmse = root_mean_squared_error(y_val, y_pred)
    mlflow.log_metric("rmse", rmse)

    with open("models/preprocessor.b", "wb") as f_out:
        pickle.dump(dv, f_out)

    mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

    mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")
# Out:
# [0]	validation-rmse:11.06892
# [1]	validation-rmse:10.13267
# [2]	validation-rmse:9.37606
# [3]	validation-rmse:8.76994
# [4]	validation-rmse:8.28596
# [5]	validation-rmse:7.90393
# [6]	validation-rmse:7.60194
# [7]	validation-rmse:7.36614
# [8]	validation-rmse:7.18190
# [9]	validation-rmse:7.03717
# [10]	validation-rmse:6.92105
# [11]	validation-rmse:6.83282
# [12]	validation-rmse:6.76298
# [13]	validation-rmse:6.70572
# [14]	validation-rmse:6.66107
# [15]	validation-rmse:6.62373
# [16]	validation-rmse:6.59346
# [17]	validation-rmse:6.56876
# [18]	validation-rmse:6.54744
# [19]	validation-rmse:6.52954
# [20]	validation-rmse:6.51533
# [21]	validation-rmse:6.50288
# [22]	validation-rmse:6.49146
# [23]	validation-rmse:6.48312
# [24]	validation-rmse:6.47554
# [25]	validation-rmse:6.46799
# [26]	validation-rmse:6.46102
# [27]	validation-rmse:6.45488
# [28]	validation-rmse:6.45073
# [29]	validation-rmse:6.44653
# [30]	validation-rmse:6.44407
# [31]	validation-rmse:6.44190
# [32]	validation-rmse:6.43969
# [33]	validation-rmse:6.43761
# [34]	validation-rmse:6.43611
# [35]	validation-rmse:6.43395
# [36]	validation-rmse:6.43255
# [37]	validation-rmse:6.43134
# [38]	validation-rmse:6.43071
# [39]	validation-rmse:6.42919
# [40]	validation-rmse:6.42816
# [41]	validation-rmse:6.42709
# [42]	validation-rmse:6.42477
# [43]	validation-rmse:6.42345
# [44]	validation-rmse:6.42249
# [45]	validation-rmse:6.42128
# [46]	validation-rmse:6.42016
# [47]	validation-rmse:6.41911
# [48]	validation-rmse:6.41758
# [49]	validation-rmse:6.41691
# [50]	validation-rmse:6.41569
# [51]	validation-rmse:6.41439
# [52]	validation-rmse:6.41270
# [53]	validation-rmse:6.41160
# [54]	validation-rmse:6.40973
# [55]	validation-rmse:6.40867
# [56]	validation-rmse:6.40758
# [57]	validation-rmse:6.40639
# [58]	validation-rmse:6.40558
# [59]	validation-rmse:6.40467
# [60]	validation-rmse:6.40359
# [61]	validation-rmse:6.40285
# [62]	validation-rmse:6.40176
# [63]	validation-rmse:6.40115
# [64]	validation-rmse:6.39996
# [65]	validation-rmse:6.39869
# [66]	validation-rmse:6.39783
# [67]	validation-rmse:6.39677
# [68]	validation-rmse:6.39639
# [69]	validation-rmse:6.39557
# [70]	validation-rmse:6.39494
# [71]	validation-rmse:6.39425
# [72]	validation-rmse:6.39315
# [73]	validation-rmse:6.39194
# [74]	validation-rmse:6.39033
# [75]	validation-rmse:6.38949
# [76]	validation-rmse:6.38842
# [77]	validation-rmse:6.38779
# [78]	validation-rmse:6.38707
# [79]	validation-rmse:6.38673
# [80]	validation-rmse:6.38611
# [81]	validation-rmse:6.38551
# [82]	validation-rmse:6.38467
# [83]	validation-rmse:6.38375
# [84]	validation-rmse:6.38333
# [85]	validation-rmse:6.38272
# [86]	validation-rmse:6.38194
# [87]	validation-rmse:6.38155
# [88]	validation-rmse:6.38053
# [89]	validation-rmse:6.37964
# [90]	validation-rmse:6.37894
# [91]	validation-rmse:6.37833
# [92]	validation-rmse:6.37790
# [93]	validation-rmse:6.37723
# [94]	validation-rmse:6.37695
# [95]	validation-rmse:6.37624
# [96]	validation-rmse:6.37602
# [97]	validation-rmse:6.37530
# [98]	validation-rmse:6.37444
# [99]	validation-rmse:6.37378
# [100]	validation-rmse:6.37287
# [101]	validation-rmse:6.37204
# [102]	validation-rmse:6.37124
# [103]	validation-rmse:6.37046
# [104]	validation-rmse:6.36976
# [105]	validation-rmse:6.36910
# [106]	validation-rmse:6.36861
# [107]	validation-rmse:6.36834
# [108]	validation-rmse:6.36777
# [109]	validation-rmse:6.36755
# [110]	validation-rmse:6.36697
# [111]	validation-rmse:6.36609
# [112]	validation-rmse:6.36557
# [113]	validation-rmse:6.36517
# [114]	validation-rmse:6.36492
# [115]	validation-rmse:6.36440
# [116]	validation-rmse:6.36388
# [117]	validation-rmse:6.36365
# [118]	validation-rmse:6.36334
# [119]	validation-rmse:6.36271
# [120]	validation-rmse:6.36189
# [121]	validation-rmse:6.36162
# [122]	validation-rmse:6.36107
# [123]	validation-rmse:6.36071
# [124]	validation-rmse:6.36027
# [125]	validation-rmse:6.35993
# [126]	validation-rmse:6.35944
# [127]	validation-rmse:6.35928
# [128]	validation-rmse:6.35878
# [129]	validation-rmse:6.35848
# [130]	validation-rmse:6.35785
# [131]	validation-rmse:6.35752
# [132]	validation-rmse:6.35725
# [133]	validation-rmse:6.35671
# [134]	validation-rmse:6.35615
# [135]	validation-rmse:6.35505
# [136]	validation-rmse:6.35456
# [137]	validation-rmse:6.35431
# [138]	validation-rmse:6.35388
# [139]	validation-rmse:6.35340
# [140]	validation-rmse:6.35312
# [141]	validation-rmse:6.35246
# [142]	validation-rmse:6.35236
# [143]	validation-rmse:6.35193
# [144]	validation-rmse:6.35159
# [145]	validation-rmse:6.35141
# [146]	validation-rmse:6.35123
# [147]	validation-rmse:6.35080
# [148]	validation-rmse:6.35057
# [149]	validation-rmse:6.35027
# [150]	validation-rmse:6.34960
# [151]	validation-rmse:6.34923
# [152]	validation-rmse:6.34885
# [153]	validation-rmse:6.34878
# [154]	validation-rmse:6.34840
# [155]	validation-rmse:6.34812
# [156]	validation-rmse:6.34773
# [157]	validation-rmse:6.34758
# [158]	validation-rmse:6.34731
# [159]	validation-rmse:6.34696
# [160]	validation-rmse:6.34633
# [161]	validation-rmse:6.34584
# [162]	validation-rmse:6.34549
# [163]	validation-rmse:6.34520
# [164]	validation-rmse:6.34494
# [165]	validation-rmse:6.34457
# [166]	validation-rmse:6.34427
# [167]	validation-rmse:6.34398
# [168]	validation-rmse:6.34379
# [169]	validation-rmse:6.34371
# [170]	validation-rmse:6.34323
# [171]	validation-rmse:6.34281
# [172]	validation-rmse:6.34251
# [173]	validation-rmse:6.34236
# [174]	validation-rmse:6.34246
# [175]	validation-rmse:6.34210
# [176]	validation-rmse:6.34143
# [177]	validation-rmse:6.34113
# [178]	validation-rmse:6.34068
# [179]	validation-rmse:6.34028
# [180]	validation-rmse:6.33983
# [181]	validation-rmse:6.33953
# [182]	validation-rmse:6.33901
# [183]	validation-rmse:6.33884
# [184]	validation-rmse:6.33870
# [185]	validation-rmse:6.33861
# [186]	validation-rmse:6.33817
# [187]	validation-rmse:6.33779
# [188]	validation-rmse:6.33746
# [189]	validation-rmse:6.33700
# [190]	validation-rmse:6.33677
# [191]	validation-rmse:6.33657
# [192]	validation-rmse:6.33615
# [193]	validation-rmse:6.33605
# [194]	validation-rmse:6.33600
# [195]	validation-rmse:6.33555
# [196]	validation-rmse:6.33540
# [197]	validation-rmse:6.33549
# [198]	validation-rmse:6.33537
# [199]	validation-rmse:6.33522
# [200]	validation-rmse:6.33489
# [201]	validation-rmse:6.33465
# [202]	validation-rmse:6.33431
# [203]	validation-rmse:6.33424
# [204]	validation-rmse:6.33410
# [205]	validation-rmse:6.33408
# [206]	validation-rmse:6.33401
# [207]	validation-rmse:6.33389
# [208]	validation-rmse:6.33353
# [209]	validation-rmse:6.33320
# [210]	validation-rmse:6.33274
# [211]	validation-rmse:6.33240
# [212]	validation-rmse:6.33221
# [213]	validation-rmse:6.33196
# [214]	validation-rmse:6.33124
# [215]	validation-rmse:6.33134
# [216]	validation-rmse:6.33147
# [217]	validation-rmse:6.33136
# [218]	validation-rmse:6.33099
# [219]	validation-rmse:6.33085
# [220]	validation-rmse:6.33050
# [221]	validation-rmse:6.33021
# [222]	validation-rmse:6.33018
# [223]	validation-rmse:6.32989
# [224]	validation-rmse:6.32989
# [225]	validation-rmse:6.32987
# [226]	validation-rmse:6.32968
# [227]	validation-rmse:6.32940
# [228]	validation-rmse:6.32908
# [229]	validation-rmse:6.32891
# [230]	validation-rmse:6.32872
# [231]	validation-rmse:6.32840
# [232]	validation-rmse:6.32820
# [233]	validation-rmse:6.32817
# [234]	validation-rmse:6.32768
# [235]	validation-rmse:6.32715
# [236]	validation-rmse:6.32688
# [237]	validation-rmse:6.32651
# [238]	validation-rmse:6.32626
# [239]	validation-rmse:6.32599
# [240]	validation-rmse:6.32579
# [241]	validation-rmse:6.32529
# [242]	validation-rmse:6.32527
# [243]	validation-rmse:6.32526
# [244]	validation-rmse:6.32527
# [245]	validation-rmse:6.32468
# [246]	validation-rmse:6.32376
# [247]	validation-rmse:6.32358
# [248]	validation-rmse:6.32336
# [249]	validation-rmse:6.32332
# [250]	validation-rmse:6.32317
# [251]	validation-rmse:6.32313
# [252]	validation-rmse:6.32295
# [253]	validation-rmse:6.32276
# [254]	validation-rmse:6.32244
# [255]	validation-rmse:6.32218
# [256]	validation-rmse:6.32208
# [257]	validation-rmse:6.32224
# [258]	validation-rmse:6.32221
# [259]	validation-rmse:6.32209
# [260]	validation-rmse:6.32094
# [261]	validation-rmse:6.32059
# [262]	validation-rmse:6.32046
# [263]	validation-rmse:6.31957
# [264]	validation-rmse:6.31936
# [265]	validation-rmse:6.31915
# [266]	validation-rmse:6.31892
# [267]	validation-rmse:6.31883
# [268]	validation-rmse:6.31859
# [269]	validation-rmse:6.31855
# [270]	validation-rmse:6.31823
# [271]	validation-rmse:6.31824
# [272]	validation-rmse:6.31817
# [273]	validation-rmse:6.31810
# [274]	validation-rmse:6.31802
# [275]	validation-rmse:6.31795
# [276]	validation-rmse:6.31771
# [277]	validation-rmse:6.31775
# [278]	validation-rmse:6.31760
# [279]	validation-rmse:6.31748
# [280]	validation-rmse:6.31759
# [281]	validation-rmse:6.31762
# [282]	validation-rmse:6.31737
# [283]	validation-rmse:6.31741
# [284]	validation-rmse:6.31710
# [285]	validation-rmse:6.31678
# [286]	validation-rmse:6.31676
# [287]	validation-rmse:6.31662
# [288]	validation-rmse:6.31633
# [289]	validation-rmse:6.31609
# [290]	validation-rmse:6.31611
# [291]	validation-rmse:6.31605
# [292]	validation-rmse:6.31542
# [293]	validation-rmse:6.31552
# [294]	validation-rmse:6.31540
# [295]	validation-rmse:6.31535
# [296]	validation-rmse:6.31537
# [297]	validation-rmse:6.31507
# [298]	validation-rmse:6.31511
# [299]	validation-rmse:6.31508
# [300]	validation-rmse:6.31508
# [301]	validation-rmse:6.31475
# [302]	validation-rmse:6.31432
# [303]	validation-rmse:6.31401
# [304]	validation-rmse:6.31406
# [305]	validation-rmse:6.31393
# [306]	validation-rmse:6.31350
# [307]	validation-rmse:6.31327
# [308]	validation-rmse:6.31330
# [309]	validation-rmse:6.31346
# [310]	validation-rmse:6.31330
# [311]	validation-rmse:6.31314
# [312]	validation-rmse:6.31326
# [313]	validation-rmse:6.31330
# [314]	validation-rmse:6.31323
# [315]	validation-rmse:6.31310
# [316]	validation-rmse:6.31292
# [317]	validation-rmse:6.31296
# [318]	validation-rmse:6.31308
# [319]	validation-rmse:6.31288
# [320]	validation-rmse:6.31292
# [321]	validation-rmse:6.31278
# [322]	validation-rmse:6.31255
# [323]	validation-rmse:6.31236
# [324]	validation-rmse:6.31216
# [325]	validation-rmse:6.31202
# [326]	validation-rmse:6.31193
# [327]	validation-rmse:6.31190
# [328]	validation-rmse:6.31135
# [329]	validation-rmse:6.31152
# [330]	validation-rmse:6.31152
# [331]	validation-rmse:6.31146
# [332]	validation-rmse:6.31139
# [333]	validation-rmse:6.31103
# [334]	validation-rmse:6.31105
# [335]	validation-rmse:6.31106
# [336]	validation-rmse:6.31091
# [337]	validation-rmse:6.31066
# [338]	validation-rmse:6.31065
# [339]	validation-rmse:6.31060
# [340]	validation-rmse:6.31073
# [341]	validation-rmse:6.31061
# [342]	validation-rmse:6.31072
# [343]	validation-rmse:6.31076
# [344]	validation-rmse:6.31079
# [345]	validation-rmse:6.31081
# [346]	validation-rmse:6.31073
# [347]	validation-rmse:6.31096
# [348]	validation-rmse:6.31089
# [349]	validation-rmse:6.31082
# [350]	validation-rmse:6.31072
# [351]	validation-rmse:6.31073
# [352]	validation-rmse:6.31082
# [353]	validation-rmse:6.31064
# [354]	validation-rmse:6.31049
# [355]	validation-rmse:6.31039
# [356]	validation-rmse:6.31026
# [357]	validation-rmse:6.31030
# [358]	validation-rmse:6.31010
# [359]	validation-rmse:6.30990
# [360]	validation-rmse:6.30973
# [361]	validation-rmse:6.30948
# [362]	validation-rmse:6.30946
# [363]	validation-rmse:6.30962
# [364]	validation-rmse:6.30947
# [365]	validation-rmse:6.30950
# [366]	validation-rmse:6.30949
# [367]	validation-rmse:6.30939
# [368]	validation-rmse:6.30951
# [369]	validation-rmse:6.30951
# [370]	validation-rmse:6.30949
# [371]	validation-rmse:6.30933
# [372]	validation-rmse:6.30936
# [373]	validation-rmse:6.30929
# [374]	validation-rmse:6.30913
# [375]	validation-rmse:6.30912
# [376]	validation-rmse:6.30911
# [377]	validation-rmse:6.30891
# [378]	validation-rmse:6.30858
# [379]	validation-rmse:6.30847
# [380]	validation-rmse:6.30842
# [381]	validation-rmse:6.30829
# [382]	validation-rmse:6.30822
# [383]	validation-rmse:6.30832
# [384]	validation-rmse:6.30815
# [385]	validation-rmse:6.30809
# [386]	validation-rmse:6.30788
# [387]	validation-rmse:6.30786
# [388]	validation-rmse:6.30763
# [389]	validation-rmse:6.30756
# [390]	validation-rmse:6.30763
# [391]	validation-rmse:6.30753
# [392]	validation-rmse:6.30756
# [393]	validation-rmse:6.30760
# [394]	validation-rmse:6.30757
# [395]	validation-rmse:6.30756
# [396]	validation-rmse:6.30740
# [397]	validation-rmse:6.30718
# [398]	validation-rmse:6.30692
# [399]	validation-rmse:6.30668
# [400]	validation-rmse:6.30656
# [401]	validation-rmse:6.30630
# [402]	validation-rmse:6.30663
# [403]	validation-rmse:6.30652
# [404]	validation-rmse:6.30646
# [405]	validation-rmse:6.30647
# [406]	validation-rmse:6.30672
# [407]	validation-rmse:6.30710
# [408]	validation-rmse:6.30719
# [409]	validation-rmse:6.30720
# [410]	validation-rmse:6.30724
# [411]	validation-rmse:6.30719
# [412]	validation-rmse:6.30731
# [413]	validation-rmse:6.30722
# [414]	validation-rmse:6.30693
# [415]	validation-rmse:6.30692
# [416]	validation-rmse:6.30704
# [417]	validation-rmse:6.30710
# [418]	validation-rmse:6.30716
# [419]	validation-rmse:6.30688
# [420]	validation-rmse:6.30687
# [421]	validation-rmse:6.30688
# [422]	validation-rmse:6.30680
# [423]	validation-rmse:6.30665
# [424]	validation-rmse:6.30658
# [425]	validation-rmse:6.30643
# [426]	validation-rmse:6.30635
# [427]	validation-rmse:6.30625
# [428]	validation-rmse:6.30634
# [429]	validation-rmse:6.30625
# [430]	validation-rmse:6.30614
# [431]	validation-rmse:6.30627
# [432]	validation-rmse:6.30618
# [433]	validation-rmse:6.30635
# [434]	validation-rmse:6.30626
# [435]	validation-rmse:6.30622
# [436]	validation-rmse:6.30621
# [437]	validation-rmse:6.30642
# [438]	validation-rmse:6.30614
# [439]	validation-rmse:6.30618
# [440]	validation-rmse:6.30619
# [441]	validation-rmse:6.30608
# [442]	validation-rmse:6.30604
# [443]	validation-rmse:6.30590
# [444]	validation-rmse:6.30583
# [445]	validation-rmse:6.30589
# [446]	validation-rmse:6.30551
# [447]	validation-rmse:6.30537
# [448]	validation-rmse:6.30539
# [449]	validation-rmse:6.30542
# [450]	validation-rmse:6.30566
# [451]	validation-rmse:6.30550
# [452]	validation-rmse:6.30539
# [453]	validation-rmse:6.30528
# [454]	validation-rmse:6.30526
# [455]	validation-rmse:6.30518
# [456]	validation-rmse:6.30513
# [457]	validation-rmse:6.30509
# [458]	validation-rmse:6.30498
# [459]	validation-rmse:6.30497
# [460]	validation-rmse:6.30491
# [461]	validation-rmse:6.30492
# [462]	validation-rmse:6.30510
# [463]	validation-rmse:6.30521
# [464]	validation-rmse:6.30515
# [465]	validation-rmse:6.30512
# [466]	validation-rmse:6.30512
# [467]	validation-rmse:6.30498
# [468]	validation-rmse:6.30480
# [469]	validation-rmse:6.30479
# [470]	validation-rmse:6.30473
# [471]	validation-rmse:6.30472
# [472]	validation-rmse:6.30458
# [473]	validation-rmse:6.30458
# [474]	validation-rmse:6.30443
# [475]	validation-rmse:6.30439
# [476]	validation-rmse:6.30454
# [477]	validation-rmse:6.30454
# [478]	validation-rmse:6.30445
# [479]	validation-rmse:6.30444
# [480]	validation-rmse:6.30448
# [481]	validation-rmse:6.30437
# [482]	validation-rmse:6.30371
# [483]	validation-rmse:6.30393
# [484]	validation-rmse:6.30390
# [485]	validation-rmse:6.30392
# [486]	validation-rmse:6.30393
# [487]	validation-rmse:6.30421
# [488]	validation-rmse:6.30441
# [489]	validation-rmse:6.30443
# [490]	validation-rmse:6.30440
# [491]	validation-rmse:6.30438
# [492]	validation-rmse:6.30437
# [493]	validation-rmse:6.30409
# [494]	validation-rmse:6.30382
# [495]	validation-rmse:6.30386
# [496]	validation-rmse:6.30407
# [497]	validation-rmse:6.30402
# [498]	validation-rmse:6.30394
# [499]	validation-rmse:6.30400
# [500]	validation-rmse:6.30403
# [501]	validation-rmse:6.30391
# [502]	validation-rmse:6.30387
# [503]	validation-rmse:6.30398
# [504]	validation-rmse:6.30406
# [505]	validation-rmse:6.30402
# [506]	validation-rmse:6.30385
# [507]	validation-rmse:6.30388
# [508]	validation-rmse:6.30374
# [509]	validation-rmse:6.30382
# [510]	validation-rmse:6.30396
# [511]	validation-rmse:6.30382
# [512]	validation-rmse:6.30389
# [513]	validation-rmse:6.30434
# [514]	validation-rmse:6.30437
# [515]	validation-rmse:6.30440
# [516]	validation-rmse:6.30432
# [517]	validation-rmse:6.30428
# [518]	validation-rmse:6.30433
# [519]	validation-rmse:6.30440
# [520]	validation-rmse:6.30426
# [521]	validation-rmse:6.30433
# [522]	validation-rmse:6.30439
# [523]	validation-rmse:6.30423
# [524]	validation-rmse:6.30429
# [525]	validation-rmse:6.30444
# [526]	validation-rmse:6.30433
# [527]	validation-rmse:6.30442
# [528]	validation-rmse:6.30429
# [529]	validation-rmse:6.30440
# [530]	validation-rmse:6.30510
# [531]	validation-rmse:6.30501
# /Users/emma_factored/learning/mlops-zoomcamp/env/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [13:56:28] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   warnings.warn(smsg, UserWarning)

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.svm import LinearSVR

mlflow.sklearn.autolog()

for model_class in (RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor, LinearSVR):

    with mlflow.start_run():

        mlflow.log_param("train-data-path", "./data/green_tripdata_2021-01.parquet")
        mlflow.log_param("valid-data-path", "./data/green_tripdata_2021-02.parquet")
        mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

        mlmodel = model_class()
        mlmodel.fit(X_train, y_train)

        y_pred = mlmodel.predict(X_val)
        rmse = root_mean_squared_error(y_val, y_pred)
        mlflow.log_metric("rmse", rmse)
# Out:
# 2024/07/16 12:43:34 WARNING mlflow.utils.autologging_utils: You are using an unsupported version of sklearn. If you encounter errors during autologging, try upgrading / downgrading sklearn to a supported version, or try upgrading MLflow.
# 2024/07/16 12:43:34 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
# 2024/07/16 12:50:38 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
# 2024/07/16 12:50:45 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
# 2024/07/16 13:11:18 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
# /Users/emma_factored/learning/mlops-zoomcamp/env/lib/python3.12/site-packages/sklearn/svm/_base.py:1235: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
logged_model = 'runs:/423806b1dcfb4e80828caf05666ac7bd/models_mlflow'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)

# %%
loaded_model
# Out:
# mlflow.pyfunc.loaded_model:
#   artifact_path: models_mlflow
#   flavor: mlflow.xgboost
#   run_id: 423806b1dcfb4e80828caf05666ac7bd

# %%
xgboost_model = mlflow.xgboost.load_model(logged_model)

# %%
xgboost_model

# %%
y_pred = xgboost_model.predict(valid)
y_pred
# Out:
# array([14.16761  ,  6.703611 , 13.780919 , ..., 13.402606 ,  6.1558385,
#         8.0104265], dtype=float32)
